# %%
import numpy as np
import pandas as pd
import ast
import pickle

# %%
games = pd.read_csv('steam.csv')
#games = games.astype(np.float32)

# %%
games.head(3)
# Out:
#    appid                   name release_date  english developer publisher  \
# 0     10         Counter-Strike   2000-11-01        1     Valve     Valve
# 1     20  Team Fortress Classic   1999-04-01        1     Valve     Valve
# 2     30          Day of Defeat   2003-05-01        1     Valve     Valve
#
#            platforms  required_age  \
# 0  windows;mac;linux             0
# 1  windows;mac;linux             0
# 2  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99

# %%
games.shape
# Out:
# (27075, 18)

# %%
games[['appid', 'name', 'developer', 'publisher', 'steamspy_tags']]
# Out:
#          appid                        name           developer  \
# 0           10              Counter-Strike               Valve
# 1           20       Team Fortress Classic               Valve
# 2           30               Day of Defeat               Valve
# 3           40          Deathmatch Classic               Valve
# 4           50   Half-Life: Opposing Force    Gearbox Software
# ...        ...                         ...                 ...
# 27070  1065230             Room of Pandora         SHEN JIAWEI
# 27071  1065570                   Cyber Gun      Semyon Maximov
# 27072  1065650            Super Star Blast         EntwicklerX
# 27073  1066700  New Yankee 7: Deer Hunters  Yustas Game Studio
# 27074  1069460                   Rune Lord    Adept Studios GD
#
#                   publisher                 steamspy_tags
# 0                     Valve        Action;FPS;Multiplayer
# 1                     Valve        Action;FPS;Multiplayer
# 2                     Valve  FPS;World War II;Multiplayer
# 3                     Valve        Action;FPS;Multiplayer
# 4                     Valve             FPS;Action;Sci-fi
# ...                     ...                           ...
# 27070           SHEN JIAWEI        Adventure;Indie;Casual
# 27071      BekkerDev Studio        Action;Indie;Adventure
# 27072           EntwicklerX           Action;Indie;Casual
# 27073  Alawar Entertainment        Indie;Casual;Adventure
# 27074  Alawar Entertainment        Indie;Casual;Adventure
#
# [27075 rows x 5 columns]

# %%
features = ['appid', 'name', 'developer', 'publisher', 'steamspy_tags']

# %%
def clean_data(x):
  if isinstance(x, list):
    return [str.lower(i.replace(" ", " ")) for i in x]
  else:
      if isinstance(x, str):
        return str.lower(x.replace(" ", " "))
      else:
        return ''

# %%
for feature in features:
  games[feature] = games[feature].apply(clean_data)

# %%
def get_important_features(data):
  important_features = []
  for i in range(0, data.shape[0]):
    important_features.append(data['name'][i]+' '+data['developer'][i]+' '+data['publisher'][i]+' '+' '+data['steamspy_tags'][i])

  return important_features

# %%
games['important_features'] = get_important_features(games)

# %%
games.head(3)
# Out:
#   appid                   name release_date  english developer publisher  \
# 0               counter-strike   2000-11-01        1     valve     valve
# 1        team fortress classic   1999-04-01        1     valve     valve
# 2                day of defeat   2003-05-01        1     valve     valve
#
#            platforms  required_age  \
# 0  windows;mac;linux             0
# 1  windows;mac;linux             0
# 2  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        action;fps;multiplayer             0            124534
# 1        action;fps;multiplayer             0              3318
# 2  fps;world war ii;multiplayer             0              3416
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
#
#    price                                 important_features
# 0   7.19  counter-strike valve valve  action;fps;multipl...
# 1   3.99  team fortress classic valve valve  action;fps;...
# 2   3.99  day of defeat valve valve  fps;world war ii;mu...

# %%
games.drop(columns=['developer', 'publisher', 'steamspy_tags'])
# Out:
#       appid                        name release_date  english  \
# 0                        counter-strike   2000-11-01        1
# 1                 team fortress classic   1999-04-01        1
# 2                         day of defeat   2003-05-01        1
# 3                    deathmatch classic   2001-06-01        1
# 4             half-life: opposing force   1999-11-01        1
# ...     ...                         ...          ...      ...
# 27070                   room of pandora   2019-04-24        1
# 27071                         cyber gun   2019-04-23        1
# 27072                  super star blast   2019-04-24        1
# 27073        new yankee 7: deer hunters   2019-04-17        1
# 27074                         rune lord   2019-04-24        1
#
#                platforms  required_age  \
# 0      windows;mac;linux             0
# 1      windows;mac;linux             0
# 2      windows;mac;linux             0
# 3      windows;mac;linux             0
# 4      windows;mac;linux             0
# ...                  ...           ...
# 27070            windows             0
# 27071            windows             0
# 27072            windows             0
# 27073        windows;mac             0
# 27074        windows;mac             0
#
#                                               categories  \
# 0      Multi-player;Online Multi-Player;Local Multi-P...
# 1      Multi-player;Online Multi-Player;Local Multi-P...
# 2                  Multi-player;Valve Anti-Cheat enabled
# 3      Multi-player;Online Multi-Player;Local Multi-P...
# 4      Single-player;Multi-player;Valve Anti-Cheat en...
# ...                                                  ...
# 27070                   Single-player;Steam Achievements
# 27071                                      Single-player
# 27072  Single-player;Multi-player;Co-op;Shared/Split ...
# 27073                          Single-player;Steam Cloud
# 27074                          Single-player;Steam Cloud
#
#                        genres  achievements  positive_ratings  \
# 0                      Action             0            124534
# 1                      Action             0              3318
# 2                      Action             0              3416
# 3                      Action             0              1273
# 4                      Action             0              5250
# ...                       ...           ...               ...
# 27070  Adventure;Casual;Indie             7                 3
# 27071  Action;Adventure;Indie             0                 8
# 27072     Action;Casual;Indie            24                 0
# 27073  Adventure;Casual;Indie             0                 2
# 27074  Adventure;Casual;Indie             0                 4
#
#        negative_ratings  average_playtime  median_playtime             owners  \
# 0                  3339             17612              317  10000000-20000000
# 1                   633               277               62   5000000-10000000
# 2                   398               187               34   5000000-10000000
# 3                   267               258              184   5000000-10000000
# 4                   288               624              415   5000000-10000000
# ...                 ...               ...              ...                ...
# 27070                 0                 0                0            0-20000
# 27071                 1                 0                0            0-20000
# 27072                 1                 0                0            0-20000
# 27073                 0                 0                0            0-20000
# 27074                 0                 0                0            0-20000
#
#        price                                 important_features
# 0       7.19  counter-strike valve valve  action;fps;multipl...
# 1       3.99  team fortress classic valve valve  action;fps;...
# 2       3.99  day of defeat valve valve  fps;world war ii;mu...
# 3       3.99  deathmatch classic valve valve  action;fps;mul...
# 4       3.99  half-life: opposing force gearbox software val...
# ...      ...                                                ...
# 27070   2.09  room of pandora shen jiawei shen jiawei  adven...
# 27071   1.69  cyber gun semyon maximov bekkerdev studio  act...
# 27072   3.99  super star blast entwicklerx entwicklerx  acti...
# 27073   5.19  new yankee 7: deer hunters yustas game studio ...
# 27074   5.19  rune lord adept studios gd alawar entertainmen...
#
# [27075 rows x 16 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix1 = count.fit_transform(games['important_features'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim1 = cosine_similarity(count_matrix1)

# %%
games[games['name'] == 'counter-strike'].index[0]
# Out:
# 0

# %%
#games = games.reset_index()
#indices = pd.Series(games.index, index=games['name']).drop_duplicates()

# %%
games.head(3)
# Out:
#   appid                   name release_date  english developer publisher  \
# 0               counter-strike   2000-11-01        1     valve     valve
# 1        team fortress classic   1999-04-01        1     valve     valve
# 2                day of defeat   2003-05-01        1     valve     valve
#
#            platforms  required_age  \
# 0  windows;mac;linux             0
# 1  windows;mac;linux             0
# 2  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        action;fps;multiplayer             0            124534
# 1        action;fps;multiplayer             0              3318
# 2  fps;world war ii;multiplayer             0              3416
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
#
#    price                                 important_features
# 0   7.19  counter-strike valve valve  action;fps;multipl...
# 1   3.99  team fortress classic valve valve  action;fps;...
# 2   3.99  day of defeat valve valve  fps;world war ii;mu...

# %%
def recommend(game):    #cosine_sim=cosine_sim1
  #indx = indices[game]
  #simScore = list(enumerate(cosine_sim1[indx]))
  #simScore = sorted(simScore, key=lambda x: x[1], reverse=True)
  #simScore = simScore[1:11]
  #game_indx = [i[0] for i in simScore]
  #return games['name'].iloc[game_indx]
  index = games[games['name'] == game].index[0]
  distances = sorted(list(enumerate(cosine_sim1[index])), reverse=True, key=lambda x: x[1])
  for i in distances[1:11]:
    print(games['name'].iloc[i[0]])

# %%
recommend('grand theft auto iv')       #, cosine_sim1)
# Out:
# grand theft auto
# grand theft auto 2
# grand theft auto v
# grand theft auto: episodes from liberty city
# grand theft auto iii
# grand theft auto: vice city
# grand theft auto: san andreas
# bully: scholarship edition
# manhunt
# l.a. noire

# %%
pickle.dump(games,open('gamesData.pkl', 'wb'))

# %%
pickle.dump(cosine_sim1,open('cosineSim.pkl', 'wb'), protocol=4)
